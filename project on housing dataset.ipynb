# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_data = pd.read_excel("housing.xlsx")

# %%
housing_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# Q1: What is the average median income of the data set and check the distribution of data using appropriate plots.
#     Please explain the distribution of the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt


average_median_income = housing_data['median_income'].mean()
print("Average Median Income: $", round(average_median_income, 3))



plt.figure(figsize=(8, 6))
plt.hist(housing_data['median_income'], bins=30, edgecolor='k')
plt.xlabel('Median Income')
plt.ylabel('Frequency')
plt.title('Distribution of Median Income')
plt.axvline(average_median_income, color='r', linestyle='dashed', linewidth=1.5, label='Mean')
plt.legend()
plt.show()
# Out:
# Average Median Income: $ 3.871

# %% [markdown]
# 2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

# %%
plt.figure(figsize=(8, 6))
plt.hist(housing_data['housing_median_age'], bins=30, edgecolor='k')
plt.xlabel('Housing Median Age')
plt.ylabel('Frequency')
plt.title('Distribution of Housing Median Age')
plt.show()

# %% [markdown]
# 3. Show with the help of visualization how median_income and median_house_values are related

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(data=housing_data, x='median_income', y='median_house_value', c='median_house_value', cmap='winter', alpha=0.6)
plt.colorbar(scatter, label='Median House Value')
plt.title('Median Income vs. Median House Value')
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.show()

# %% [markdown]
# 4. Create a dataset by deleting the corresponding examples from the dataset for which total_bedrooms are not available.

# %%
# Create a new dataset by removing rows with missing total_bedrooms
cleaned_data = housing_data.dropna(subset=['total_bedrooms']).copy()

# Print the first few rows of the cleaned dataset
cleaned_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %% [markdown]
# 5. Create a dataset by filling the missing data with the mean value of the total_bedrooms in the original dataset.

# %%
# Fill missing total_bedrooms with the mean value
filled_data = housing_data.copy()
mean_total_bedrooms = filled_data['total_bedrooms'].mean()
filled_data['total_bedrooms'].fillna(mean_total_bedrooms, inplace=True)


filled_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %% [markdown]
# 6. Write a programming construct (create a user-defined function) to calculate the median value of the dataset wherever required.

# %%
# User-defined function to calculate median
def calculate_median(data):
    sorted_data = sorted(data)
    n = len(sorted_data)
    if n % 2 == 0:
        median = (sorted_data[n // 2] + sorted_data[(n // 2) - 1]) / 2
    else:
        median = sorted_data[n // 2]
    return median

data = [4, 2, 7, 1, 5]
result = calculate_median(data)
print("Median:", result)
# Out:
# Median: 4

# %% [markdown]
# 7. Plot latitude versus longitude and explain your observations.

# %%
# Plot latitude versus longitude
plt.figure(figsize=(8, 6))
plt.scatter(housing_data['longitude'], housing_data['latitude'], alpha=0.4)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Latitude vs Longitude')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=housing_data, x='longitude', y='latitude', hue='ocean_proximity', palette='coolwarm', legend=True)
sns.kdeplot(data=housing_data, x='longitude', y='latitude', cmap='coolwarm', levels=10, linewidths=1.5, alpha=0.5)
plt.title('Latitude vs. Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# 8. Create a dataset for which the ocean_proximity is 'Near ocean'.

# %%
# Create a new dataset for ocean_proximity 'Near ocean'
near_ocean_data = housing_data[housing_data['ocean_proximity'] == 'NEAR OCEAN'].copy()


near_ocean_data.head()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850    -124.17     41.80                  16         2739           480.0
# 1851    -124.30     41.80                  19         2672           552.0
# 1852    -124.23     41.75                  11         3159           616.0
# 1853    -124.21     41.77                  17         3461           722.0
# 1854    -124.19     41.78                  15         3140           714.0
#
#       population  households  median_income  median_house_value  \
# 1850        1259         436         3.7557              109400
# 1851        1298         478         1.9797               85800
# 1852        1343         479         2.4805               73200
# 1853        1947         647         2.5795               68400
# 1854        1645         640         1.6654               74600
#
#      ocean_proximity
# 1850      NEAR OCEAN
# 1851      NEAR OCEAN
# 1852      NEAR OCEAN
# 1853      NEAR OCEAN
# ...

# %% [markdown]
# 9. Find the mean and median of the median income for the dataset created in question 8

# %%
# Calculate mean and median of median income for near_ocean_data
mean_median_income = near_ocean_data['median_income'].mean()
median_median_income = near_ocean_data['median_income'].median()

# Print the mean and median values
print("Mean Median Income:", mean_median_income)
print("Median Median Income:", median_median_income)
# Out:
# Mean Median Income: 4.005784800601957
# Median Median Income: 3.64705

# %% [markdown]
# 10. Please create a new column named 'total_bedroom_size'. If the total bedrooms are 10 or less, it should be quoted as 'small'. If the total bedrooms are 11 or more but less than 1000, it should be quoted as 'medium'. Otherwise, it should be considered 'large'.

# %%
housing_data['total_bedroom_size'] = pd.cut(housing_data['total_bedrooms'], bins=[0, 10, 1000, float('inf')],
                                            labels=['small', 'medium', 'large'])


housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY
#
#   total_bedroom_size
# 0             medium
# 1              large
# ...
